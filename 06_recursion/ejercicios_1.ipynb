# %% [markdown]
# # Ejercicios de clase

# %% [markdown]
# ---
#
# ### 1. **Sumatoria de una lista**
#    Implementa una función recursiva que reciba una lista de números y devuelva la suma de todos sus elementos.
#
#    ```python
#    def sumatoria(lista):
#        pass
#    ```
#
#    **Ejemplo:**
#    ```python
#    sumatoria([1, 2, 3, 4, 5])  # Output: 15
#    sumatoria([10, -5, 7])      # Output: 12
#    ```

# %% [markdown]
# **🧭 Planeación obligatoria — hazlo antes de escribir código**
# 1. **Caso base:** lista vacía → ¿cuál es la suma?
# 2. **Caso recursivo (en palabras):** si ya tienes la suma del resto de la lista, ¿cómo obtienes la suma total?
# 3. **Traza a mano:** para `sumatoria([1, 2, 3])`, dibuja las llamadas y qué retorna cada una.

# %% [markdown]
# ## Ejercicio de clase: devolver sumatoria de elementos de una lista siempre y cuando los elementos adyacentes tengan una diferencia de 1 ascendentemente

# %% [markdown]
# **🧭 Planeación obligatoria**
# 1. **Caso base:** ¿qué pasa con una lista vacía o de un solo elemento?
# 2. **Caso recursivo (en palabras):** compara el elemento actual con el siguiente — si la diferencia es exactamente 1 (ascendente), ¿lo sumas y sigues? Si no, ¿qué pasa con el resto de la lista?
# 3. **Traza a mano:** para `[3, 4, 5, 8, 9]`, dibuja las llamadas y marca qué elementos entran en la suma y cuáles no.

# %% [markdown]
# ### Ejercicio de clase: dado un string alfanumérico S, devuelva el string sin números. Además, si el número (dígito) está antes de una letra, replica esa letra la cantidad de veces del dígito.

# %% [markdown]
# **🧭 Planeación obligatoria**
# 1. **Caso base:** string vacío → ¿qué retornas?
# 2. **Caso recursivo (en palabras):** ¿qué haces si el carácter actual es un dígito y el siguiente es una letra? ¿Qué haces si el carácter actual es una letra normal? ¿Cómo evitas que los dígitos aparezcan en el resultado final?
# 3. **Traza a mano:** para un ejemplo corto como `"2a"`, dibuja las llamadas y qué retorna cada una.

# %% [markdown]
# ---
#
# ### 2. **Contar elementos en una lista anidada**
#    Escribe una función recursiva que cuente el número total de elementos en una lista, considerando que puede contener sublistas anidadas.
#
#    ```python
#    def contar_elementos(lista):
#        pass
#    ```
#
#    **Ejemplo:**
#    ```python
#    contar_elementos([1, [2, 3], [4, [5, 6]]])  # Output: 6
#    contar_elementos([[], [1, [2, 3]], 4])      # Output: 4
#    ```

# %% [markdown]
# **🧭 Planeación obligatoria**
# 1. **Caso base:** lista vacía → 0 elementos.
# 2. **Caso recursivo (en palabras):** si el primer elemento es una lista, ¿qué haces con él? Si es un número, ¿qué haces? ¿Cómo combinas eso con el conteo del resto de la lista?
# 3. **Traza a mano:** para `contar_elementos([1, [2, 3], 4])`, dibuja las llamadas y qué retorna cada una.

# %% [markdown]
# ---
#
# ### 3. **Número de dígitos de un número**
#    Implementa una función recursiva que cuente cuántos dígitos tiene un número entero positivo.
#
#    ```python
#    def contar_digitos(n):
#        pass
#    ```
#
#    **Ejemplo:**
#    ```python
#    contar_digitos(12345)   # Output: 5
#    contar_digitos(987654)  # Output: 6
#    ```

# %% [markdown]
# **🧭 Planeación obligatoria**
# 1. **Caso base:** ¿cuál es el número más pequeño (de un solo dígito) que puedes responder directamente, sin recursión?
# 2. **Caso recursivo (en palabras):** si ya sabes cuántos dígitos tiene `n // 10`, ¿cómo obtienes la cantidad de dígitos de `n`?
# 3. **Traza a mano:** para `contar_digitos(482)`, dibuja las llamadas y qué retorna cada una.

# %% [markdown]
# ---
#
# ### 4. **Producto de dos números usando sumas**
#    Implementa una función recursiva para calcular el producto de dos números enteros positivos utilizando solo sumas.
#
#    ```python
#    def producto(a, b):
#        pass
#    ```
#
#    **Ejemplo:**
#    ```python
#    producto(3, 4)   # Output: 12
#    producto(5, 6)   # Output: 30
#    ```

# %% [markdown]
# **🧭 Planeación obligatoria**
# 1. **Caso base:** ¿cuánto es cualquier número multiplicado 0 veces?
# 2. **Caso recursivo (en palabras):** si ya tienes `a * (b - 1)` (usando solo sumas para llegar ahí), ¿cómo obtienes `a * b`?
# 3. **Traza a mano:** para `producto(3, 4)`, dibuja las llamadas y qué retorna cada una.

# %% [markdown]
# ---
#
# ### 5. **Comprobar si una palabra es palíndromo**
#    Escribe una función recursiva que determine si una cadena es un palíndromo.
#
#    ```python
#    def es_palindromo(cadena):
#        pass
#    ```
#
#    **Ejemplo:**
#    ```python
#    es_palindromo("radar")     # Output: True
#    es_palindromo("reconocer") # Output: True
#    es_palindromo("python")    # Output: False
#    ```

# %% [markdown]
# **🧭 Planeación obligatoria**
# 1. **Caso base:** ¿cuándo una cadena es trivialmente palíndromo sin seguir comparando? (longitud 0 o 1)
# 2. **Caso recursivo (en palabras):** ¿qué comparas primero (el primer y el último carácter), y qué subproblema le queda al resto de la cadena?
# 3. **Traza a mano:** para `es_palindromo("radar")`, dibuja las llamadas y en qué punto se decide `True` o `False`.
