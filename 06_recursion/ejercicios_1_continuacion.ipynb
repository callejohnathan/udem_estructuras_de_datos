# %% [markdown]
# # 1

# %% [markdown]
# ---
#
# ### 6. **Máximo común divisor (MCD)**
#    Implementa una función recursiva que calcule el máximo común divisor (MCD) de dos números.
#
#    ```python
#    def mcd(a, b):
#        pass
#    ```
#
#    **Ejemplo:**
#    ```python
#    mcd(48, 18)  # Output: 6
#    mcd(101, 103) # Output: 1
#    ```

# %% [markdown]
# **🧭 Planeación obligatoria**
# 1. **Caso base:** ¿cuándo puedes responder el MCD directamente sin seguir recursionando? (pista: algoritmo de Euclides, `b == 0`)
# 2. **Caso recursivo (en palabras):** `mcd(a, b)` en términos de `mcd(b, a % b)` — ¿por qué ese subproblema es "más pequeño" y garantiza que la recursión termine?
# 3. **Traza a mano:** para `mcd(48, 18)`, dibuja las llamadas y qué retorna cada una.

# %% [markdown]
# ---
#
# ### 7. **Verificar si un número es primo**
#    Crea una función recursiva que determine si un número es primo.
#
#    ```python
#    def es_primo(n, divisor=2):
#        pass
#    ```
#
#    **Ejemplo:**
#    ```python
#    es_primo(7)   # Output: True
#    es_primo(12)  # Output: False
#    ```

# %% [markdown]
# **🧭 Planeación obligatoria**
# 1. **Caso base(s):** ¿qué determina directamente que `n` es primo o no, sin seguir probando divisores? (piensa en `n < 2`, y en cuándo `divisor * divisor > n`)
# 2. **Caso recursivo (en palabras):** si `divisor` no divide a `n`, ¿qué haces? Si sí lo divide, ¿qué retornas?
# 3. **Traza a mano:** para `es_primo(7, 2)`, dibuja las llamadas y en qué divisor se decide la respuesta.

# %% [markdown]
# ---
#
# ### 8. **Suma de los dígitos de un número**
#    Implementa una función recursiva que sume los dígitos de un número entero positivo.
#
#    ```python
#    def suma_digitos(n):
#        pass
#    ```
#
#    **Ejemplo:**
#    ```python
#    suma_digitos(123)  # Output: 6
#    suma_digitos(987)  # Output: 24
#    ```

# %% [markdown]
# **🧭 Planeación obligatoria**
# 1. **Caso base:** un número de un solo dígito → la suma de sus dígitos es él mismo.
# 2. **Caso recursivo (en palabras):** si ya tienes la suma de los dígitos de `n // 10`, ¿cómo obtienes la suma de los dígitos de `n`?
# 3. **Traza a mano:** para `suma_digitos(123)`, dibuja las llamadas y qué retorna cada una.

# %% [markdown]
# ---
#
# ### 9. **Búsqueda binaria recursiva**
#    Implementa una función recursiva que realice una búsqueda binaria en una lista ordenada.
#
#    ```python
#    def busqueda_binaria(lista, objetivo, inicio=0, fin=None):
#        pass
#    ```
#
#    **Ejemplo:**
#    ```python
#    busqueda_binaria([1, 3, 5, 7, 9], 5)  # Output: True
#    busqueda_binaria([2, 4, 6, 8, 10], 7) # Output: False
#    ```

# %% [markdown]
# **🧭 Planeación obligatoria**
# 1. **Caso base(s):** ¿cuándo el rango de búsqueda queda vacío (no está el elemento)? ¿Cuándo el elemento del medio ES el objetivo?
# 2. **Caso recursivo (en palabras):** si el objetivo es menor que el elemento del medio, ¿en qué mitad sigues buscando? ¿Y si es mayor?
# 3. **Traza a mano:** para `busqueda_binaria([1, 3, 5, 7, 9], 7)`, dibuja las llamadas y cómo se va reduciendo el rango `[inicio, fin]`.

# %% [markdown]
# ---
#
# ### 10. **Permutaciones de una cadena**
#    Crea una función recursiva que genere todas las permutaciones de una cadena de texto.
#
#    ```python
#    def permutaciones(cadena, prefijo=""):
#        pass
#    ```
#
#    **Ejemplo:**
#    ```python
#    permutaciones("abc")
#    # Output:
#    # abc
#    # acb
#    # bac
#    # bca
#    # cab
#    # cba
#    ```
#
# ---

# %% [markdown]
# **🧭 Planeación obligatoria**
# Este problema es de **recursión múltiple** (varias llamadas recursivas por nivel), como `fib` o `subconjuntos` en `teoria_recursion.ipynb`.
# 1. **Caso base:** cadena vacía → ¿qué imprime/retorna?
# 2. **Caso recursivo (en palabras):** para cada carácter de la cadena, ¿qué haces con él y con el resto? (aquí hay una llamada recursiva por cada elección posible de carácter)
# 3. **Traza a mano:** para `permutaciones("ab")`, dibuja el árbol de decisiones: qué letra se elige primero en cada rama, y qué queda por permutar en cada una.
