# %% [markdown]
# # Ejercicios - 1

# %% [markdown]
# ## Implementación base Lista Enlazada

# %%
from base import NodeSingly, SinglyLinkedList

# %% [markdown]
# ## Implementar una pila con listas enlazadas

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Repasa las operaciones de una pila: `push` (agregar), `pop` (quitar y devolver), `peek` (consultar sin quitar). ¿Qué extremo de la lista enlazada (cabeza o cola) te conviene usar como "tope" de la pila para que `push` y `pop` sean O(1)?
# 2. Revisa la API de `SinglyLinkedList` en `base.py` (`append`, `delete_and_return_first`, `delete_and_return_last`, `head`, `tail`, `__len__`) **antes** de escribir nada. ¿Qué método ya existente corresponde a cada operación de la pila?
# 3. Dibuja el estado de la lista antes y después de un `push` y de un `pop`, usando un ejemplo pequeño (3 elementos).

# %% [markdown]
# ### **1️⃣ Revertir una Lista Enlazada Simple**
# 📌 **Descripción**: Dada una lista enlazada simple, escribe un algoritmo que invierta su orden, es decir, que el último nodo se convierta en el primero, el penúltimo en el segundo, y así sucesivamente.
# 🔹 **Restricción**: La solución debe modificar los punteros de la lista y no usar estructuras auxiliares como pilas o arreglos.
# 🔍 **Ejemplo**:
# ```
# Entrada: 1 → 2 → 3 → 4 → 5 → None
# Salida: 5 → 4 → 3 → 2 → 1 → None
# ```

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Dibuja `1 → 2 → 3` y decide qué variables vas a necesitar para no perder ningún nodo mientras reviertes (pista: necesitas "recordar" el nodo anterior, el actual y el siguiente).
# 2. Antes de reasignar `current.next` para que apunte hacia atrás, ¿qué tienes que guardar primero? Si no lo guardas, ¿qué se pierde? (repasa el "error clásico" de la teoría).
# 3. Escribe en palabras el orden exacto de las reasignaciones que ocurren en cada paso del recorrido.
# 4. ¿Cuál es tu caso de parada, y qué debe apuntar `head` (o el equivalente) al terminar?

# %% [markdown]
# ---
#
# ### **2️⃣ Detectar y Eliminar Ciclos en una Lista Enlazada**
# 📌 **Descripción**: Dada una lista enlazada, determina si contiene un ciclo (es decir, si algún nodo apunta a un nodo anterior en la lista). Si existe un ciclo, elimínalo.
# 🔹 **Restricción**: No puedes modificar los valores de los nodos, solo los punteros.
# 🔍 **Ejemplo**:
# ```
# Entrada: A → B → C → D → E → C (ciclo en C)
# Salida: A → B → C → D → E → None
# ```

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. ¿Qué técnica de la teoría te permite detectar el ciclo sin usar espacio auxiliar? Nómbrala.
# 2. Dibuja el ejemplo `A → B → C → D → E → C` y marca a mano varias iteraciones de `slow`/`fast` hasta que se encuentren dentro del ciclo.
# 3. Una vez que `slow` y `fast` se encuentran, ¿cómo encontrarías el nodo exacto donde **empieza** el ciclo? Intenta razonarlo con el dibujo antes de buscar la fórmula.
# 4. Con el nodo donde empieza el ciclo identificado, ¿qué puntero exactamente tienes que poner en `None`, y sobre cuál nodo?

# %% [markdown]
# ---
#
# ### **3️⃣ Fusionar Dos Listas Enlazadas Ordenadas**
# 📌 **Descripción**: Dadas dos listas enlazadas simples ordenadas en orden ascendente, fusionarlas en una única lista también ordenada.
# 🔹 **Restricción**: No crear una nueva lista; modificar los punteros de los nodos existentes.
# 🔍 **Ejemplo**:
# ```
# Entrada: 1 → 3 → 5 → None  y  2 → 4 → 6 → None
# Salida: 1 → 2 → 3 → 4 → 5 → 6 → None
# ```

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Dibuja las dos listas de ejemplo (`1 → 3 → 5` y `2 → 4 → 6`) una encima de la otra.
# 2. En cada paso, ¿cómo decides cuál de los dos nodos "cabeza actual" va primero en la lista resultante? ¿Cuál puntero avanza y cuál se queda esperando?
# 3. ¿Qué nodo usas como ancla para ir construyendo el resultado sin perder la referencia a su inicio? (pista: piensa en el nodo dummy que viste en teoría).
# 4. ¿Qué haces cuando una de las dos listas se acaba antes que la otra?

# %% [markdown]
# ---
#
# ### **4️⃣ Rotar una Lista Enlazada K Veces**
# 📌 **Descripción**: Dada una lista enlazada simple y un número entero **K**, rota la lista **K** veces a la derecha.
# 🔹 **Restricción**: La rotación debe realizarse modificando los punteros, sin reconstruir la lista desde cero.
# 🔍 **Ejemplo**:
# ```
# Entrada: 1 → 2 → 3 → 4 → 5 → None, K = 2
# Salida: 4 → 5 → 1 → 2 → 3 → None
# ```

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Dibuja `1 → 2 → 3 → 4 → 5` y marca cuál nodo debe ser la nueva cabeza y cuál el nuevo último nodo después de rotar `K = 2` posiciones.
# 2. ¿Cómo identificas el nuevo `tail` (el nodo cuyo `next` debe apuntar a `None`) y el nuevo `head`, recorriendo la lista una sola vez o el menor número de veces posible?
# 3. Escribe en orden: ¿primero conectas el viejo último nodo con la vieja cabeza (para "cerrar el círculo"), o primero cortas la lista en el nuevo punto? ¿Por qué ese orden y no el otro?
# 4. ¿Qué debe pasar si `K` es mayor que el tamaño de la lista?

# %% [markdown]
# ---
#
# ### **5️⃣ Encontrar el Nodo Medio de una Lista Enlazada**
# 📌 **Descripción**: Dada una lista enlazada simple, encuentra el nodo que está en el centro de la lista.
# 🔹 **Restricción**: No puedes contar los nodos explícitamente antes de encontrar el nodo medio.
# 🔍 **Ejemplo**:
# ```
# Entrada: 1 → 2 → 3 → 4 → 5 → None
# Salida: 3
# ```
# Si hay un número par de nodos, devuelve el segundo nodo medio.

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. ¿Qué técnica de la teoría aplica directamente aquí? Nómbrala antes de escribir código.
# 2. Traza a mano, nodo por nodo, cómo avanzan `slow` y `fast` sobre `1 → 2 → 3 → 4 → 5`. ¿En qué nodo termina `slow`?
# 3. Repite la traza con una lista de longitud par (por ejemplo `1 → 2 → 3 → 4`) para verificar que tu criterio de parada devuelve el **segundo** nodo medio, como pide el enunciado.

# %% [markdown]
# ---
#
# ### **6️⃣ Intercambiar Pares de Nodos en una Lista Enlazada**
# 📌 **Descripción**: Intercambia los nodos en parejas dentro de una lista enlazada simple.
# 🔹 **Restricción**: No modificar los valores de los nodos, solo los punteros.
# 🔍 **Ejemplo**:
# ```
# Entrada: 1 → 2 → 3 → 4 → 5 → None
# Salida: 2 → 1 → 4 → 3 → 5 → None
# ```

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Dibuja los primeros 4 nodos de `1 → 2 → 3 → 4 → 5` como dos parejas: `(1,2)` y `(3,4)`, con el `5` suelto al final.
# 2. Para la primera pareja, ¿qué punteros tienes que reasignar para que quede `2 → 1 → 3`? Escribe el orden exacto — ¿cuál reasignación pierde la referencia al resto de la lista si la haces primero?
# 3. ¿Cómo conectas el resultado de una pareja ya intercambiada con la siguiente pareja?
# 4. ¿Qué pasa si el número de nodos es impar (como el `5` suelto en el ejemplo)? ¿y si la lista tiene 0 o 1 nodos?

# %% [markdown]
# ---
#
# ### **7️⃣ Clonar una Lista Enlazada con Punteros Aleatorios**
# 📌 **Descripción**: Dada una lista enlazada donde cada nodo contiene una referencia adicional a cualquier otro nodo de la lista (o `None`), crea una copia exacta de la lista original.
# 🔹 **Restricción**: La copia debe ser una nueva estructura independiente, no debe compartir nodos con la original.
# 🔍 **Ejemplo**:
# ```
# Nodo: [Dato, Next, Random]
# Entrada: A → B → C → None (con referencias aleatorias)
# Salida: Copia exacta de la lista con referencias intactas.
# ```

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Dibuja la lista original `A → B → C` con sus flechas `next` **y** sus flechas `random` (inventa a qué apunta el random de cada nodo).
# 2. Si copias cada nodo por separado y usas un diccionario `original → copia`, ¿en qué orden tienes que recorrer la lista para poder asignar el `random` de cada copia correctamente?
# 3. Variante sin estructuras auxiliares: ¿qué significa "intercalar" cada copia justo después de su original? Dibuja cómo se vería `A → A' → B → B' → C → C'` y explica cómo usarías esa intercalación para copiar el `random` sin diccionario.
# 4. ¿En qué paso final separas la lista original de la copia, sin romper ninguna de las dos?

# %% [markdown]
# ---
#
# ### **8️⃣ Reorganizar una Lista Enlazada en un Patrón Alternante**
# 📌 **Descripción**: Dada una lista enlazada simple, reorganízala de manera que el primer nodo se conecte al último, el segundo al penúltimo, el tercero al tercero desde el final, y así sucesivamente.
# 🔹 **Restricción**: Modificar solo los punteros, sin usar estructuras auxiliares.
# 🔍 **Ejemplo**:
# ```
# Entrada: 1 → 2 → 3 → 4 → 5 → 6 → None
# Salida: 1 → 6 → 2 → 5 → 3 → 4 → None
# ```

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Dibuja la lista de ejemplo `1 → 2 → 3 → 4 → 5 → 6` y marca dónde termina la primera mitad y dónde empieza la segunda.
# 2. ¿Cómo encuentras esa mitad sin contar los nodos primero? (pista: el modelo de dos punteros que ya viste en teoría).
# 3. Antes de intercalar, ¿qué necesitas hacer con la segunda mitad? Dibuja cómo queda después de ese paso previo.
# 4. Ahora, con las dos mitades listas, escribe en palabras y en orden cómo vas tomando un nodo de cada mitad alternadamente sin perder la referencia al resto.

# %% [markdown]
# ---
#
# ### **9️⃣ Determinar si una Lista Enlazada es un Palíndromo**
# 📌 **Descripción**: Dada una lista enlazada, determina si los valores almacenados en sus nodos forman un palíndromo.
# 🔹 **Restricción**: Debe hacerse en O(n) de tiempo y O(1) de espacio adicional.
# 🔍 **Ejemplo**:
# ```
# Entrada: 1 → 2 → 3 → 2 → 1 → None
# Salida: True
# ```

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Con el ejemplo `1 → 2 → 3 → 2 → 1`, dibuja qué pasa si primero encuentras el nodo medio (dos punteros lento/rápido, como en teoría) y luego reviertes la segunda mitad in-place.
# 2. ¿Qué nodos necesitas guardar antes de revertir la segunda mitad, para no perder la referencia a la primera mitad?
# 3. Escribe en palabras el orden de pasos: encontrar medio → revertir segunda mitad → comparar desde ambos extremos hacia el centro.
# 4. ¿Qué pasa con el nodo del medio si la lista tiene un número impar de elementos? ¿afecta la comparación?
