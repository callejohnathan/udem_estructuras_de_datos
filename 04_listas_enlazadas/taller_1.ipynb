# %% [markdown]
# # Clases Base

# %% [markdown]
# ## Lista Enlazada Simple

# %%
from base import NodeSingly, SinglyLinkedList
from base import NodeDoubly, DoublyLinkedList
from base import NodeCircular, CircularLinkedList

# %% [markdown]
# ## Lista Doblemente Enlazada

# %% [markdown]
# ## Lista Enlazada Circular

# %% [markdown]
# ## Ejercicios de clase

# %% [markdown]
# Crear una lista enlazada con los valores de cada caracter
# siguiendo estas restricciones:
#
# * Si me encuentro un número y después tiene una letra
#     * -> se elimina el número
#     * -> se replica la letra la cantidad de veces del número
#     * -> se ignora la letra que ya se agregó

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Inventa un ejemplo pequeño de cadena de entrada (por ejemplo `"3ab2c"`) y aplica la regla a mano, carácter por carácter, hasta que tengas clara la regla en tus propias palabras.
# 2. ¿Qué necesitas recordar mientras recorres la cadena? (por ejemplo: si el carácter anterior era un número, y cuál).
# 3. Dibuja cómo va creciendo la lista enlazada nodo a nodo mientras procesas tu ejemplo.
# 4. ¿Qué método de `SinglyLinkedList` te sirve para ir agregando cada carácter resultante?

# %% [markdown]
# # Ejercicios

# %% [markdown]
# ---
#
# ## 🟢 Ejercicio 1: Lista Enlazada Simple
#
# **Enunciado:**
# Implementa una función que reciba una **lista enlazada simple** de enteros y un valor `x`. Tu tarea es **eliminar el primer nodo que contenga ese valor**.
#
# * Si el valor no existe, la lista debe permanecer igual.
# * No puedes usar listas de Python (`list`) para resolver el problema, solo la implementación de lista enlazada.
#
# **Ejemplo:**
#
# ```
# Entrada: [5 → 8 → 3 → 10], x = 3
# Salida: [5 → 8 → 10]
# ```
#
# 👉 **Punto de aprendizaje**: práctica con el manejo de punteros, casos especiales (eliminación en cabeza, en medio, o cuando no existe el valor).

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Dibuja `5 → 8 → 3 → 10` y marca cuál nodo hay que eliminar si `x = 3`.
# 2. ¿Qué nodo necesitas tener guardado (el anterior al que vas a eliminar) para poder desenlazarlo sin recorrer la lista dos veces?
# 3. ¿Qué cambia si el valor a eliminar está en la cabeza? ¿tu solución maneja ese caso sin un `if` especial, o lo necesita?
# 4. ¿Qué pasa si el valor no existe en la lista?

# %% [markdown]
# ---
#
# ## 🔵 Ejercicio 2: Lista Doblemente Enlazada
#
# **Enunciado:**
# Dada una **lista doblemente enlazada**, implementa una función que **inserte un nodo con valor `x` en la posición `p` (basada en índice 0)**.
#
# * Si `p = 0`, se inserta al inicio.
# * Si `p` es mayor al tamaño de la lista, se inserta al final.
#
# **Ejemplo:**
#
# ```
# Entrada: [1 ⇄ 2 ⇄ 4], x = 3, p = 2
# Salida: [1 ⇄ 2 ⇄ 3 ⇄ 4]
# ```
#
# 👉 **Punto de aprendizaje**: reforzar la diferencia entre `prev` y `next`, y el manejo de enlaces dobles.

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Dibuja `1 ⇄ 2 ⇄ 4` y marca dónde debe quedar el nuevo nodo `3` para `p = 2`.
# 2. En una lista doblemente enlazada, insertar en el medio implica actualizar 4 flechas: el `next` y `prev` del nuevo nodo, y el `next`/`prev` de sus dos vecinos. Nómbralas las 4 antes de escribir código.
# 3. ¿En qué orden las reasignas para no perder la referencia a ningún nodo vecino en el camino?
# 4. ¿Qué casos borde tienes que resolver aparte? (`p = 0`, `p` mayor o igual al tamaño de la lista)

# %% [markdown]
# ---
#
# ## 🔴 Ejercicio 3: Lista Circular
#
# **Enunciado:**
# Se tiene una **lista circular simple** que representa a jugadores en un juego. Implementa una función que, dado un número `k`, **simule `k` pasos de turno y devuelva el valor del jugador al que le toca jugar**.
#
# **Ejemplo:**
#
# ```
# Jugadores: [A → B → C → D → (A otra vez)], k = 5
# Salida: "B"
# (orden: A → B → C → D → A → B)
# ```
#
# 👉 **Punto de aprendizaje**: aplicar la circularidad para recorrer indefinidamente, reforzar el concepto de que nunca hay `None`.

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Dibuja el círculo `A → B → C → D → (vuelve a A)` y marca a mano, turno por turno, los 5 pasos hasta llegar a `k = 5`.
# 2. ¿Qué patrón de recorrido visto en teoría (do-while) usas para avanzar sin caer en un bucle infinito, dado que aquí no hay `None` que te detenga?
# 3. Si `k` es mucho más grande que el número de jugadores (por ejemplo `k = 1000` con 4 jugadores), ¿hay una forma de evitar dar cientos de vueltas completas innecesarias? (pista: ¿qué operación aritmética captura "dar una vuelta completa"?)
