# %% [markdown]
# # Clases Base

# %% [markdown]
# ## Lista Enlazada Simple

# %%
from base import NodeSingly, SinglyLinkedList
from base import NodeDoubly, DoublyLinkedList
from base import NodeCircular, CircularLinkedList

# %% [markdown]
# ## Lista Doblemente Enlazada

# %% [markdown]
# ## Lista Enlazada Circular

# %% [markdown]
# # Ejercicios

# %% [markdown]
# ---
#
# ## Punto 1 — Filtrar valores mayores que K (Lista Enlazada Simple)
#
# Dada una **lista enlazada simple de números enteros**, elimine **todos los nodos cuyo valor sea mayor que un número `K`**.
#
# La función debe modificar la lista **sin crear una nueva lista**.
#
# ## Entrada
#
# Una lista enlazada simple:
#
# ```
# 4 → 7 → 2 → 9 → 1 → 6
# ```
#
# y un número:
#
# ```
# K = 5
# ```
#
# ## Salida esperada
#
# ```
# 4 → 2 → 1
# ```

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Dibuja `4 → 7 → 2 → 9 → 1 → 6` y marca cuáles nodos hay que eliminar para `K = 5`.
# 2. A diferencia de un ejercicio donde eliminas un solo nodo con un valor puntual, aquí puedes tener que eliminar **varios nodos, incluso consecutivos**, y posiblemente empezando desde la cabeza. Si eliminas dos nodos seguidos, ¿tu puntero `prev` se mueve en esa iteración, o se queda igual? Piénsalo con el dibujo antes de programar.
# 3. ¿Cómo manejas el caso en que los primeros nodos (incluida la cabeza) son justamente los que hay que eliminar?
# 4. Escribe en palabras el criterio para avanzar `current` y, por separado, el criterio para avanzar `prev` en cada iteración — no siempre son el mismo.

# %% [markdown]
# ## Punto 2 — Detectar el primer valor repetido (Lista Enlazada Simple)
#
# Dada una **lista enlazada simple de números enteros**, determine **cuál es el primer valor que aparece más de una vez en la lista**.
#
# Si ningún valor se repite, la función debe retornar `None`.
#
# ## Entrada
#
# Lista enlazada:
#
# ```
# 3 → 7 → 4 → 9 → 7 → 2
# ```
#
# ## Salida
#
# ```
# 7
# ```
#
# porque es el **primer valor que aparece nuevamente** al recorrer la lista.
#
# ## Otro ejemplo
#
# Entrada:
#
# ```
# 1 → 5 → 8 → 3
# ```
#
# Salida:
#
# ```
# None
# ```

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Recorre a mano `3 → 7 → 4 → 9 → 7 → 2` y decide qué necesitas ir guardando en cada paso para saber si un valor "ya lo habías visto".
# 2. ¿Qué estructura auxiliar (fuera de la lista enlazada) te permite consultar "¿ya vi este valor?" en O(1)? El enunciado no prohíbe usar una, a diferencia de otros ejercicios que sí exigen resolver solo con punteros — revisa bien la consigna.
# 3. ¿Cuál es tu condición de parada: cuándo dejas de recorrer, y qué devuelves si ningún valor se repite?

# %% [markdown]
# ## Punto 3 — Verificar si la lista es palíndroma (Lista Doblemente Enlazada)
#
# Dada una **lista doblemente enlazada**, determine si la secuencia de valores es **palíndroma**, es decir, si se lee igual **de izquierda a derecha y de derecha a izquierda**.
#
# La solución debe aprovechar la naturaleza **doblemente enlazada** de la estructura.
#
# ## Entrada
#
# Lista doble:
#
# ```
# 1 ⇄ 4 ⇄ 7 ⇄ 4 ⇄ 1
# ```
#
# ## Salida
#
# ```
# True
# ```
#
# ## Otro ejemplo
#
# Entrada:
#
# ```
# 2 ⇄ 3 ⇄ 5 ⇄ 6
# ```
#
# Salida:
#
# ```
# False
# ```

# %% [markdown]
# **🧠 Antes de programar (planea en papel):**
# 1. Dibuja `1 ⇄ 4 ⇄ 7 ⇄ 4 ⇄ 1` y marca dos punteros: uno empezando en `head` que avanza con `next`, y otro empezando en `tail` que avanza con `prev`.
# 2. ¿Cuál es la condición de parada cuando los dos punteros se cruzan o se encuentran?
# 3. **Compara con el ejercicio de palíndromo sobre lista simple** (`ejercicios_1`, ejercicio 9): allá no tenías `prev`, así que había que encontrar el medio y revertir la segunda mitad. Aquí, ¿qué te ahorra tener `prev` disponible?
# 4. ¿Necesitas encontrar primero cuál es el `tail`? ¿tu lista doble ya lo tiene guardado, o hay que recorrer para encontrarlo?
