# %% [markdown]
# # 📘 Ejercicios Básicos de Grafos

# %% [markdown]
# # 🌟 Definiciones Base

# %% [markdown]
# ---
#
# ## 🛠️ Clase Grafo usando Lista de Adyacencia

# %%
from base import GraphL

g = GraphL()
g.add_edge(1, 3)
g.add_edge(2, 10, directed=False)
g.add_edge(3, 1, directed=False)
g.add_edge(4, 6)
print(g)

# %% [markdown]
# ---
#
# ## 🛠️ Clase Grafo usando Matriz de Adyacencia

# %%
from base import GraphM

g = GraphM()
g.add_edge(1, 3)
g.add_edge(2, 10, directed=False)
g.add_edge(3, 1, directed=False)
g.add_edge(4, 6)
print(g)

# %% [markdown]
# # 📝 Ejercicios propuestos

# %% [markdown]
# ## 🧩 Ejercicio 1: Crear un Grafo Pequeño
#
# - Crea un grafo no dirigido con los vértices {A, B, C, D} y las aristas: A-B, A-C, B-D.
# - Muestra el grafo usando la **lista de adyacencia**.
#
# 👉 **Tip**: Como es no dirigido, agrega las conexiones en ambos sentidos.

# %% [markdown]
# **🧭 Antes de programar:** ¿qué representación pide el enunciado (lista o matriz)? ¿el grafo es dirigido o no dirigido — qué palabra exacta del enunciado te lo dice? Dibuja en papel los 4 vértices y las 3 aristas antes de escribir la primera línea de código.

# %% [markdown]
# ---
#
# ## 🧩 Ejercicio 2: Verificar conexión (Lista de Adyacencia)
#
# - Escribe una función `existe_conexion(grafo, u, v)` que devuelva `True` si existe una conexión de `u` a `v`.
#
# 👉 **Pista (sin darte la respuesta):** con `GraphL`, los vecinos de un nodo viven en `grafo.adj_list[u]`, que es una lista de Python. ¿Qué operador de Python te permite preguntar "¿está `v` dentro de esta lista?" en una sola expresión?
#
# Prueba con el grafo creado en el ejercicio 1.

# %% [markdown]
# **🧭 Antes de programar:** con la representación que ya tienes (lista de adyacencia), ¿cómo se ve exactamente "existe una arista entre `u` y `v`" en esa estructura de datos concreta (`grafo.adj_list`)? No hay ningún recorrido ni algoritmo involucrado — es una sola consulta directa. Escribe en papel qué expresión de Python devolvería `True`/`False` para 2-3 pares de nodos del grafo del ejercicio 1 (uno conectado, uno no) antes de programar la función.

# %% [markdown]
# ---
#
# ## 🧩 Ejercicio 3: Crear una Matriz de Adyacencia
#
# - Crea un grafo dirigido usando **matriz de adyacencia** con 4 vértices (0, 1, 2, 3).
# - Agrega las aristas: 0 -> 1, 0 -> 2, 1 -> 2, 2 -> 3.
# - Muestra la matriz.

# %% [markdown]
# **🧭 Antes de programar:** este ejercicio pide explícitamente matriz y grafo dirigido. Dibuja los 4 vértices y las 4 aristas dirigidas (con flechas, no líneas) en papel, y luego dibuja la matriz 4x4 vacía junto al dibujo, marcando a mano qué celdas deberían quedar en 1. Verifica que tu matriz **no** sea simétrica (si lo fuera, algo se te olvidó sobre "dirigido").

# %% [markdown]
# ---
#
# ## 🧩 Ejercicio 4: Verificar conexión (Matriz de Adyacencia)
#
# - Escribe una función `existe_conexion_matriz(grafo, u, v)` que devuelva `True` si existe una conexión de `u` a `v` en la matriz.
#
# 👉 **Pista (sin darte la respuesta):** con `GraphM`, la matriz vive en `grafo.adj_matrix` y los nombres de los vértices en `grafo.nodes` (en ese orden). Para consultar la conexión entre dos vértices necesitas convertir cada nombre en su **posición** dentro de `grafo.nodes` antes de indexar la matriz. ¿Qué método de las listas de Python te da la posición de un elemento?
#
# Prueba con el grafo del ejercicio 3.

# %% [markdown]
# **🧭 Antes de programar:** ¿en qué se diferencia consultar una arista en una matriz frente a hacerlo en una lista? Escribe en papel la traducción "nombre de vértice → posición en `nodes`" para el grafo del ejercicio 3, y luego resuelve a mano 2-3 consultas de ejemplo (una que exista y una que no) antes de programar la función.

# %% [markdown]
# ---
#
# ## 🧩 Ejercicio 5: Convertir Lista de Adyacencia a Matriz
#
# - Escribe una función que convierta una representación de **lista de adyacencia** a una **matriz de adyacencia**.
#
# 👉 **Pista**: Necesitarás saber el número de vértices y mapearlos a índices.

# %% [markdown]
# **🧭 Antes de programar:** dibuja a mano la lista de adyacencia de entrada y, al lado, una matriz vacía (filas y columnas = todos los vértices, en algún orden que tú elijas). Para cada arista `u -> v` de la lista, ¿qué celda exacta de la matriz tienes que marcar con un 1? Resuelve un ejemplo pequeño (3-4 nodos) completamente a mano antes de escribir la función. Recuerda decidir primero si tu conversión debe asumir grafo dirigido o no dirigido.

# %% [markdown]
# ---
#
# # 🚀 Resumen de lo aprendido
#
# - Crear grafos simples en ambas representaciones.
# - Buscar conexiones específicas.
# - Visualizar cómo se estructura internamente cada representación.
#
# ✨ **Recuerda:** Entender estas representaciones es clave para los algoritmos de recorrido y búsqueda que veremos más adelante.
#
# ---
