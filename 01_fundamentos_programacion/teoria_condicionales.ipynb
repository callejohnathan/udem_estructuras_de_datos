# %% [markdown]
# ---
#
# # 📌 Condicionales en Python
#
# ## 1️⃣ ¿Qué es un condicional?
# Los condicionales permiten ejecutar bloques de código dependiendo de si una condición es **verdadera** (`True`) o **falsa** (`False`). En Python, usamos `if`, `elif` y `else`.
#
# Una **condición** es simplemente una expresión que Python evalúa y reduce a `True` o `False`. Todo lo demás — `elif`, `else`, operadores lógicos — es maquinaria para combinar y encadenar esas evaluaciones booleanas.
#
# ---
#
# ## 2️⃣ Sintaxis básica
# ```python
# edad = 18
# if edad >= 18:
#     print("Eres mayor de edad")
# ```
#
# ```python
# temperatura = 15
# if temperatura > 20:
#     print("Hace calor 🌞")
# else:
#     print("Hace frío ❄️")
# ```
# 🔹 Si la condición en `if` es `False`, se ejecuta el `else`.
#
# ```python
# nota = 85
# if nota >= 90:
#     print("Excelente! 🎉")
# elif nota >= 70:
#     print("Aprobado ✅")
# else:
#     print("Reprobado ❌")
# ```
# 🔹 Se ejecuta el **primer** bloque `if`/`elif` que sea `True`; los demás se ignoran, aunque también serían `True`.
#
# ---
#
# ## 3️⃣ Operadores de comparación
# | Operador  | Descripción          | Ejemplo (`a = 5`, `b = 10`) |
# |-----------|----------------------|-----------------------------|
# | `==`      | Igual a              | `a == b` ➝ `False` |
# | `!=`      | Diferente de         | `a != b` ➝ `True` |
# | `>`       | Mayor que            | `a > b` ➝ `False` |
# | `<`       | Menor que            | `a < b` ➝ `True` |
# | `>=`      | Mayor o igual que    | `a >= b` ➝ `False` |
# | `<=`      | Menor o igual que    | `a <= b` ➝ `True` |
#
# ---
#
# ## 4️⃣ Operadores lógicos
# | Operador  | Descripción          | Ejemplo (`x = 5`, `y = 10`) |
# |-----------|----------------------|-----------------------------|
# | `and`     | Ambas condiciones deben ser `True` | `(x > 0) and (y > 0)` → `True` |
# | `or`      | Al menos una condición es `True` | `(x > 0) or (y < 0)` → `True` |
# | `not`     | Invierte el resultado | `not (x > 0)` → `False` |
#
# ```python
# usuario = "admin"
# clave = "1234"
#
# if usuario == "admin" and clave == "1234":
#     print("Acceso permitido 🔓")
# else:
#     print("Acceso denegado 🔒")
# ```
#
# ⚡ **Evaluación corta (short-circuit):** Python deja de evaluar en cuanto el resultado ya está decidido. En `False and funcion()`, `funcion()` **nunca se ejecuta** porque el `and` ya sabe que el resultado es `False`. En `True or funcion()`, tampoco se ejecuta, porque el `or` ya sabe que el resultado es `True`. Esto importa cuando esas llamadas tienen efectos secundarios (imprimir, modificar una lista, etc.) — si esperas que se ejecuten y el `and`/`or` las "salta", tu programa se comporta distinto a lo que esperabas.
#
# ⚠️ **Agrupa con paréntesis** cuando combines `and`/`or` en la misma condición — sin ellos, la precedencia de operadores puede no ser la que intuyes:
# ```python
# if (x > 0 and y < 20) or (z > 30):  # ✅ explícito, sin ambigüedad
#     print("Se ejecuta")
# ```
#
# ---
#
# ## 5️⃣ ¿Qué valores se evalúan como `True` o `False`?
# Python **convierte automáticamente** ciertos valores a booleano cuando aparecen en un `if`. Esto es útil, pero también es la fuente de errores lógicos más común en condicionales — porque el código "corre sin error" y aun así hace lo que no querías.
#
# ### 🔹 Se evalúan como `False` (*falsy*)
# `None` · `0` (y `0.0`, `0j`) · `""` (cadena vacía) · `[]` · `{}` · `set()` · `False`
#
# Todo lo demás se evalúa como `True`.
#
# ```python
# lista = []
# if not lista:
#     print("La lista está vacía")  # se ejecuta: [] es falsy
# ```
#
# ⚠️ **El peligro:** `if precio:` no es lo mismo que "¿el precio es válido?" — es "¿el precio es distinto de 0?". Si `precio = 0` es un caso legítimo en tu programa (por ejemplo, un producto gratis), `if precio:` lo trata como si no existiera. Prefiere comparaciones **explícitas**:
# ```python
# if len(lista) == 0:   # ✅ explícito: "la lista está vacía"
#     print("Lista vacía")
# # en vez de la versión implícita: if not lista:
# ```
#
# ### 🔹 `is` vs `==`
# `==` compara **valores**; `is` compara **identidad** (si son el mismo objeto en memoria). Para comparar con `None`, usa siempre `is`:
# ```python
# x = None
# if x is None:      # ✅ correcto y es la convención de Python
#     print("x es None")
# # x == None también "funciona", pero no es la forma idiomática
# ```
#
# ---
#
# ## 6️⃣ `in` y `not in`
# ```python
# frutas = ["manzana", "banana", "pera"]
#
# if "banana" in frutas:
#     print("Sí, hay bananas 🍌")
#
# if "sandía" not in frutas:
#     print("No hay sandía 🍉")
# ```
#
# ---
#
# ## 7️⃣ `any()` y `all()` para condiciones sobre colecciones
# ```python
# numeros = [0, 0, 1, 0]
# if any(numeros):                    # True si al menos un valor es truthy
#     print("Hay un número diferente de cero")
#
# numeros = [1, 2, 3, 4]
# if all(n > 0 for n in numeros):     # True si TODOS son truthy
#     print("Todos los números son positivos")
# ```
#
# ---
#
# ## 8️⃣ Condicional en una línea (ternario)
# ```python
# edad = 20
# mensaje = "Mayor de edad" if edad >= 18 else "Menor de edad"
# ```
# 🔹 Úsalo solo cuando el código siga siendo fácil de leer en una línea — si la condición es compleja, un `if/else` normal es más claro.
#
# ---
#
# ## 9️⃣ `match-case` (Python 3.10+)
# ```python
# opcion = 2
# match opcion:
#     case 1:
#         print("Opción 1 seleccionada")
#     case 2:
#         print("Opción 2 seleccionada")
#     case _:
#         print("Opción inválida")
# ```
#
# ---
#
# ## 🎯 Ejemplo completo
# ```python
# nombre = "Juan"
# edad = 17
#
# if edad >= 18:
#     print(f"{nombre} puede votar 🗳️")
# elif edad >= 16:
#     print(f"{nombre} puede conducir 🚗 pero no votar.")
# else:
#     print(f"{nombre} es menor de edad.")
# ```
#
# ---

# %% [markdown]
# ## 🧠 Modelo mental: la tabla de traza para condicionales
#
# Con un `if/elif/else` la trampa no es "no entender la sintaxis" — es asumir cuál rama se ejecuta **sin comprobarlo con cuidado**, sobre todo cuando hay varias condiciones encadenadas o combinadas con `and`/`or`. El hábito que necesitas instalar: para cada entrada distinta que te interese probar, **evalúa la condición completa a mano, en orden, antes de mirar el código correr.**
#
# Toma esta función (todavía no la corras):
# ```python
# def clasificar_envio(peso_kg, es_urgente, es_internacional):
#     if es_internacional and peso_kg > 20:
#         return "rechazado"
#     elif es_urgente and peso_kg <= 5:
#         return "expreso"
#     elif peso_kg <= 5:
#         return "estandar"
#     elif peso_kg <= 20:
#         return "carga_media"
#     else:
#         return "carga_pesada"
# ```
#
# Antes de correrla, arma una tabla de traza: una fila por cada combinación de entrada que te interese probar, y ve marcando **qué condición evaluaste y si dio `True` o `False`**, hasta encontrar la primera que dispara el `return`.
#
# | `peso_kg` | `es_urgente` | `es_internacional` | ¿`es_internacional and peso_kg>20`? | ¿`es_urgente and peso_kg<=5`? | ¿`peso_kg<=5`? | Resultado |
# |---|---|---|---|---|---|---|
# | 3 | `True` | `False` | `False` | `True` | — (ni se evalúa) | `"expreso"` |
# | 3 | `False` | `False` | `False` | `False` | `True` | `"estandar"` |
# | 25 | `False` | `True` | `True` | — | — | `"rechazado"` |
# | 10 | `True` | `False` | `False` | `False` (10 > 5) | `False` | ¿cuál sigue? |
#
# 📌 Nota la última fila: la dejamos incompleta a propósito. **Complétala tú** siguiendo la cadena `elif` hasta el final antes de correr el código.
#
# ✍️ **Ahora te toca a ti:** escoge 3 combinaciones de entrada propias (incluye al menos un caso borde, como `peso_kg = 5` exactamente, o `peso_kg = 20` exactamente) y arma tu propia tabla de traza en papel, prediciendo el resultado de cada una. Solo después escribe el código en la celda de abajo y compáralo con tu predicción.
#
# ⚠️ **Por qué importa este hábito:** en un `if/elif/else` solo se ejecuta la **primera** rama que sea `True` — todas las que siguen se ignoran, aunque también lo sean. Si no trazas el orden exacto en que Python evalúa cada condición, es muy fácil "adivinar" una rama equivocada y quedar convencido de que el código está mal cuando en realidad el error está en tu lectura, no en el código.

# %%
# Escribe aquí clasificar_envio(...) y prueba los casos que trazaste a mano.
# Compara el resultado real contra tu predicción antes de seguir.

# %% [markdown]
# # 📌 **Errores Comunes en Condiciones en Python y Cómo Solucionarlos** 🐍💡
#
# Cuando los estudiantes comienzan a trabajar con condicionales en Python, es común encontrar ciertos **errores lógicos y sintácticos**. Estos errores pueden llevar a resultados inesperados o a fallos en la ejecución del código. Aquí te dejo una **guía sistemática** para **identificar, entender y solucionar** estos errores de manera efectiva. 🚀
#
# ---
#
# ## 🎯 **1. Guía Sistemática de Pensamiento para Depuración de Condiciones**
# Antes de corregir un error en un condicional, sigue estos pasos sistemáticos:
#
# 1️⃣ **Lee la condición en voz alta**
#    📌 **Objetivo:** Entender lo que estás intentando evaluar.
#    💡 **Pregunta clave:** ¿Expresa lo que realmente quiero verificar?
#
# 2️⃣ **Revisa si la condición devuelve `True` o `False`**
#    📌 **Objetivo:** Asegurar que la expresión devuelve un booleano.
#    💡 **Herramienta:** Usa `print()` para verificar la evaluación de la condición.
#
#    ```python
#    x = 5
#    print(x > 3)  # Debería imprimir True o False
#    ```
#
# 3️⃣ **Verifica el uso correcto de operadores de comparación y lógicos**
#    📌 **Objetivo:** Detectar errores en el uso de `==`, `!=`, `<`, `>`, `and`, `or`, etc.
#    💡 **Pregunta clave:** ¿Estoy comparando correctamente los valores?
#
# 4️⃣ **Comprueba el tipo de datos involucrados**
#    📌 **Objetivo:** Asegurar que las comparaciones son entre tipos compatibles.
#    💡 **Herramienta:** Usa `type()` para verificar el tipo de cada variable.
#
#    ```python
#    x = "10"
#    print(type(x))  # str
#    ```
#
# 5️⃣ **Identifica valores inesperados**
#    📌 **Objetivo:** Prevenir errores por valores vacíos, `None`, listas vacías, etc.
#    💡 **Herramienta:** Usa `print()` para inspeccionar valores antes de compararlos.
#
# 6️⃣ **Usa `elif` en lugar de `if` independientes cuando sea necesario**
#    📌 **Objetivo:** Asegurar que solo se ejecuta un bloque de código.
#    💡 **Pregunta clave:** ¿Estoy evaluando condiciones mutuamente excluyentes?
#
# ---
#
# ## 🚨 **Errores Comunes y Cómo Solucionarlos**
#
# ### ❌ **Error 1: Usar `=` en lugar de `==` en una condición**
# 📌 **Causa:** `=` es el operador de asignación, pero en condicionales necesitamos `==` (comparación).
#
# ```python
# x = 10
#
# if x = 10:  # ❌ SyntaxError: invalid syntax
#     print("X es 10")
# ```
#
# ✅ **Solución:** Usar `==` para comparar valores.
# ```python
# if x == 10:  # ✅ Correcto
#     print("X es 10")
# ```
#
# ---
#
# ### ❌ **Error 2: Comparar tipos de datos incompatibles**
# 📌 **Causa:** Intentar comparar un número con una cadena.
#
# ```python
# x = "10"
#
# if x > 5:  # ❌ TypeError: '>' not supported between instances of 'str' and 'int'
#     print("x es mayor que 5")
# ```
#
# ✅ **Solución:** Convertir el tipo de datos antes de comparar.
# ```python
# if int(x) > 5:  # ✅ Correcto
#     print("x es mayor que 5")
# ```
#
# ---
#
# ### ❌ **Error 3: Evaluar directamente valores que pueden ser `Falsy`**
# 📌 **Causa:** En Python, `None`, `0`, `""`, `[]`, `{}` son `False` cuando se evalúan en un `if`.
#
# ```python
# usuarios = []
#
# if usuarios:  # ❌ No se ejecutará porque una lista vacía es False
#     print("Tenemos usuarios")
# else:
#     print("No hay usuarios")
# ```
#
# ✅ **Solución:** Comparar explícitamente con `len() > 0` o `is not None`.
# ```python
# if len(usuarios) > 0:  # ✅ Correcto
#     print("Tenemos usuarios")
# ```
#
# ---
#
# ### ❌ **Error 4: Usar `or` en lugar de `and` (o viceversa)**
# 📌 **Causa:** Confundir `and` y `or` al combinar condiciones.
#
# ```python
# edad = 25
# trabaja = False
#
# if edad > 18 or trabaja:  # ❌ Permite a alguien de 25 sin trabajo pasar la condición
#     print("Puede aplicar al crédito")
# ```
#
# ✅ **Solución:** Usar `and` cuando ambas condiciones deben cumplirse.
# ```python
# if edad > 18 and trabaja:  # ✅ Correcto
#     print("Puede aplicar al crédito")
# ```
#
# ---
#
# ### ❌ **Error 5: Usar `if` en lugar de `elif`, generando múltiples evaluaciones innecesarias**
# 📌 **Causa:** Al usar `if` en vez de `elif`, Python evalúa todas las condiciones, incluso si una ya es `True`.
#
# ```python
# nota = 85
#
# if nota >= 90:
#     print("Excelente")
# if nota >= 70:  # ❌ Se ejecuta incluso si la primera ya fue True
#     print("Aprobado")
# else:
#     print("Reprobado")
# ```
#
# ✅ **Solución:** Usar `elif` para evitar evaluaciones innecesarias.
# ```python
# if nota >= 90:
#     print("Excelente")
# elif nota >= 70:  # ✅ Correcto
#     print("Aprobado")
# else:
#     print("Reprobado")
# ```
#
# ---
#
# ### ❌ **Error 6: No usar `is` para comparar con `None`**
# 📌 **Causa:** Usar `==` para comparar con `None` no es la mejor práctica.
#
# ```python
# x = None
#
# if x == None:  # ❌ Funciona, pero no es recomendable
#     print("x es None")
# ```
#
# ✅ **Solución:** Usar `is None`.
# ```python
# if x is None:  # ✅ Correcto
#     print("x es None")
# ```
#
# ---
#
# ### ❌ **Error 7: No agrupar condiciones con paréntesis en evaluaciones complejas**
# 📌 **Causa:** Sin paréntesis, Python evalúa las condiciones con precedencia incorrecta.
#
# ```python
# x = 5
# y = 10
# z = 15
#
# if x > 0 and y < 20 or z > 30:  # ❌ Confuso, ¿cuál se evalúa primero?
#     print("Se ejecuta")
# ```
#
# ✅ **Solución:** Usar paréntesis para agrupar condiciones.
# ```python
# if (x > 0 and y < 20) or (z > 30):  # ✅ Correcto
#     print("Se ejecuta")
# ```
#
# ---
#
# ## 🚀 **Conclusión: Pensamiento Lógico para Evitar Errores**
# ✔ **Verifica siempre que la condición devuelva `True` o `False`.**
# ✔ **Usa `print()` para depurar y ver qué valores tienen las variables antes de comparar.**
# ✔ **Evita confusiones con `and` y `or`, usa paréntesis si es necesario.**
# ✔ **Compara `None` con `is`, no con `==`.**
# ✔ **Prefiere `elif` en lugar de múltiples `if` cuando las condiciones son excluyentes.**
# ✔ **Comprueba que los tipos de datos sean compatibles antes de comparar.**
#
# ---
