# %% [markdown]
# # 🌿 Ejercicios Intermedios: Árboles Binarios y de Búsqueda (BST)
#
# Este notebook está diseñado para practicar conceptos intermedios sobre árboles binarios y árboles binarios de búsqueda. Todos los ejercicios parten del supuesto de que ya tienes implementadas las clases `NodoBinario` o `NodoBST` y sus árboles envoltorios (`ArbolBinario` o `ArbolBST`) — puedes usar las de `base.py`.
#
# > 🧭 Antes de cada ejercicio vas a encontrar una celda **"Antes de programar"**. Respóndela primero (a mano, en papel o en tus propias palabras en la misma celda) usando el modelo mental de `teoria_arboles.ipynb`: ¿qué necesito de mis hijos? ¿qué le paso hacia abajo? ¿en qué orden visito los nodos? Dibuja un árbol pequeño y traza la recursión antes de escribir código. Saltarte este paso es exactamente el hábito que queremos romper.
#
# ---

# %%
from base import BinaryNode, BinaryTree

# %% [markdown]
# ---
#
# ## 🔁 Ejercicio 1: Recorrido en orden (inorden)
#
# Implementa una función `inorden(nodo)` que recorra el árbol y devuelva una lista con los valores en **orden ascendente** (izquierda → raíz → derecha).
#
# > 📌 Este recorrido es especialmente útil en árboles BST para recuperar los valores ordenados.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - ¿Cuál de los 4 órdenes de visita (preorden, inorden, postorden, BFS por niveles) necesitas aquí? Ya sabes la respuesta por el nombre del ejercicio — la pregunta real es **por qué** ese orden y no otro.
# - Dibuja un árbol pequeño (5-6 nodos, que sea BST) en papel. Escribe, en el orden en que tu función debería visitarlos, la secuencia de valores esperada.
# - ¿En qué momento exacto de la recursión (antes de bajar a la izquierda, entre bajar a la izquierda y bajar a la derecha, o después de ambas) se "guarda" el valor del nodo actual?

# %% [markdown]
# ---
#
# ## 🔁 Ejercicio 2: Recorrido preorden y postorden
#
# Implementa dos funciones:
# - `preorden(nodo)` → raíz → izquierda → derecha
# - `postorden(nodo)` → izquierda → derecha → raíz
#
# > 🔍 Usa estas funciones para practicar la navegación recursiva sobre los nodos.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - Sobre el mismo árbol que dibujaste en el ejercicio anterior, escribe a mano la secuencia esperada de `preorden` y, por separado, la de `postorden`.
# - Compara las tres secuencias (inorden, preorden, postorden) que ya tienes escritas para el mismo árbol: ¿en qué se parecen? ¿en qué cambia únicamente el momento en que aparece el valor del nodo actual respecto a sus dos hijos?

# %% [markdown]
# ---
#
# ## 📏 Ejercicio 3: Altura del árbol
#
# Crea una función `altura(nodo)` que calcule la altura de un árbol binario, definida como la longitud del camino más largo desde la raíz hasta una hoja.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - ¿Este problema es post-order o pre-order? Es decir: ¿necesitas algo *de* tus hijos para responder, o necesitas pasarles algo *hacia abajo*?
# - ¿Cuál es el caso base? ¿Qué debería devolver el árbol vacío para que la fórmula de combinación funcione también en una hoja?
# - Dibuja un árbol pequeño y desbalanceado (por ejemplo, una rama de 4 nodos y otra de 1). Llena una tabla nodo por nodo, de las hojas hacia la raíz, con lo que `altura(nodo)` debería devolver en cada uno — igual que en `teoria_arboles.ipynb`.

# %% [markdown]
# ---
#
# ## 🍃 Ejercicio 4: Contar hojas
#
# Crea una función `contar_hojas(nodo)` que cuente cuántos nodos hoja (sin hijos) hay en el árbol.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - ¿Qué necesitas de cada hijo para responder cuántas hojas tiene el árbol completo? (pista: es el mismo esqueleto que `altura`, pero cambia qué se combina)
# - ¿Cuál es el caso especial que identifica a una hoja? ¿Cómo se ve eso en términos de `nodo.left` y `nodo.right`?
# - Sobre tu árbol de ejemplo, marca a mano cuáles nodos son hoja y suma cuántas hay en cada subárbol antes de sumar el total.

# %% [markdown]
# ---
#
# ## 🔍 Ejercicio 5: Verificar si un valor está en el árbol
#
# Implementa una función `existe(nodo, valor)` que indique si un valor dado está presente en el árbol (retorna `True` o `False`).
#
# > 📎 Aplica especialmente la lógica de búsqueda de BST si está disponible.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - Si el árbol es un `BinaryTree` genérico (sin invariante de orden), ¿por qué tienes que revisar *ambos* subárboles en cada nodo?
# - Si en cambio supieras que el árbol es un BST, ¿qué te permitiría descartar uno de los dos subárboles sin revisarlo? Conecta esto con la analogía de búsqueda binaria que viste en `teoria_arboles.ipynb`.
# - Escribe a mano, para un árbol BST pequeño y un valor que no está, la secuencia de comparaciones y descartes que haría tu función antes de devolver `False`.

# %% [markdown]
# ---
#
# ## ♻️ Ejercicio 6: Espejar un árbol (inverso)
#
# Crea una función `espejar(nodo)` que invierta el árbol binario, intercambiando izquierda y derecha en cada nodo.
#
# > 🔄 Se espera que un nuevo árbol sea una imagen en espejo del original.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - ¿Qué necesitas construir primero: el subárbol izquierdo espejado, el derecho espejado, o no importa el orden? ¿Por qué?
# - Dibuja un árbol pequeño y, al lado, dibuja a mano cómo se ve espejado. Verifica: ¿el valor de cada nodo cambia, o solo cambia su posición (izquierda/derecha)?
# - ¿Qué le tienes que asignar al `.left` y al `.right` del nodo actual una vez que ya espejaste a sus hijos?

# %% [markdown]
# ---
#
# ## 🧮 Ejercicio 7: Suma de todos los nodos
#
# Crea una función `suma_nodos(nodo)` que calcule la suma total de los valores numéricos en el árbol.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - ¿Qué patrón es este: post-order o pre-order? Compáralo con `contar_nodos` que ya viste resuelto en `teoria_arboles.ipynb` — ¿qué cambia y qué se mantiene igual?
# - ¿Cuál es el caso base y por qué tiene que ser `0` (y no, por ejemplo, `None`)?

# %% [markdown]
# ---
#
# ## 🌿 Ejercicio 8: Verificar si un árbol es un BST válido
#
# Implementa una función `es_bst(nodo, min_val=None, max_val=None)` que verifique si la estructura cumple con las reglas de un árbol de búsqueda:
# - Subárbol izquierdo < nodo < subárbol derecho
#
# > ⚠️ Este ejercicio requiere validar recursivamente los rangos válidos.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - Fíjate en la firma de la función: ya trae los parámetros `min_val` y `max_val`. Eso es una pista fuerte de que este es el patrón **pre-order** de "pasar información hacia abajo" que viste en `teoria_arboles.ipynb` — el mismo que se usó ahí para la profundidad.
# - ¿Por qué **no basta** con comparar cada nodo solo contra su padre directo? Dibuja un árbol pequeño donde un nodo cumpla la regla frente a su padre inmediato, pero rompa el invariante BST frente a un abuelo — ese es el caso que este ejercicio te obliga a atrapar.
# - Cuando bajas a la izquierda, ¿cuál de los dos límites (`min_val` o `max_val`) se actualiza, y a qué valor? ¿Y cuando bajas a la derecha?

# %% [markdown]
# ---
#
# ## 📊 Ejercicio 9: Niveles del árbol (recorrido por niveles)
#
# Crea una función `niveles(nodo)` que imprima o retorne los valores del árbol agrupados por nivel (nivel 0, 1, 2, ...).
#
# > 📚 Puedes usar una estructura de cola para hacer recorrido BFS.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - ¿Por qué este problema no se resuelve bien con una recursión simple izquierda/derecha, y en cambio pide una **cola** (BFS)?
# - Dibuja un árbol pequeño de 3 niveles y simula a mano el recorrido: dibuja la cola en cada paso (qué entra, qué sale) hasta vaciarla. Anota en qué momento sabes que "se acabó" un nivel y empieza el siguiente.
# - Repasa el ejemplo de `por_niveles` con `deque` que ya viste en `teoria_arboles.ipynb` — aquí necesitas además **agrupar** por nivel, no solo visitar en ese orden. ¿Qué información extra necesitas guardar para saber a qué nivel pertenece cada nodo que sacas de la cola?

# %% [markdown]
# ---
#
# ## 🧩 Ejercicio 10: Encontrar el ancestro común más cercano (LCA)
#
# Dado un árbol BST y dos valores, crea una función `lca(nodo, v1, v2)` que devuelva el nodo que representa el ancestro común más cercano entre ambos valores.
#
# > 🧠 Aplica la propiedad de los BST para decidir hacia qué subárbol avanzar.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - El árbol es un BST — usa esa propiedad. Si `v1` y `v2` son ambos menores que `nodo.value`, ¿en qué subárbol tienen que estar los dos, necesariamente? ¿Y si ambos son mayores?
# - ¿Cuándo dejas de poder "bajar" hacia un solo lado? Ese es exactamente el nodo que buscas — piensa por qué.
# - Dibuja un BST pequeño y elige dos valores en hojas distintas. Traza a mano, nodo por nodo, las comparaciones que haría tu función hasta encontrar el punto donde `v1` y `v2` "se separan".
