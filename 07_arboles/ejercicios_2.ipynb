# %% [markdown]
# # 🌳 Ejercicios Avanzados: Árboles Binarios y de Búsqueda (BST)
#
# Este conjunto de ejercicios está pensado para reforzar tus habilidades avanzadas de programación con árboles binarios y árboles binarios de búsqueda. Aquí aplicarás conceptos de recursividad, estructuras auxiliares, análisis de propiedades y diseño algorítmico.
#
# ## ✅ Consejos
#
# - Usa estructuras auxiliares (pilas, colas, diccionarios) cuando sea necesario
# - Antes de programar, **dibuja ejemplos** para entender el patrón — cada ejercicio trae una celda "Antes de programar" para guiarte, pero complétala tú mismo/a, a mano, antes de escribir código
# - Prueba tus funciones con árboles desbalanceados y no triviales 🧪

# %%
from base import BinaryNode, BinaryTree

# %% [markdown]
# ---
#
# ## 🔁 Ejercicio 1: Recorrido inorden iterativo
#
# Implementa una versión **no recursiva** del recorrido inorden usando una pila.
# - Entrada: nodo raíz
# - Salida: lista con los valores en orden inorden
#
# > 💡 Ideal para repasar el uso de estructuras auxiliares en árboles.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - El inorden recursivo que ya escribiste en `ejercicios_1.ipynb` funciona porque el **call stack** de Python guarda, implícitamente, "a dónde volver". Aquí tienes que hacer esa pila explícita tú mismo/a.
# - Sobre un árbol pequeño, simula a mano: en cada paso, ¿apilas el nodo actual y bajas a la izquierda, o desapilas, visitas, y bajas a la derecha? Dibuja el contenido de la pila paso a paso hasta vaciarla.
# - ¿Cuándo terminas de bajar por la izquierda y empiezas a desapilar?

# %% [markdown]
# ---
#
# ## 💡 Ejercicio 2: Comprobar si dos árboles son idénticos
#
# Crea una función `son_identicos(nodo1, nodo2)` que determine si dos árboles binarios tienen la misma estructura y valores.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - Aquí recorres **dos árboles a la vez**, nodo a nodo. ¿Qué necesitas de cada par de subárboles (izquierdo1 vs izquierdo2, derecho1 vs derecho2) para decidir si los nodos actuales son parte de árboles idénticos? Es post-order: combinas con un `and`.
# - Piensa los casos base con cuidado: ¿qué pasa si ambos nodos son `None`? ¿Si uno es `None` y el otro no? ¿Si ambos existen pero tienen valores distintos?
# - Dibuja dos árboles pequeños casi iguales, con una sola diferencia (un valor cambiado, o un hijo de más en uno de los dos), y traza a mano en qué par de nodos tu función debería devolver `False` por primera vez.

# %% [markdown]
# ---
#
# ## 🧠 Ejercicio 3: Reconstruir un árbol desde inorden y preorden
#
# Dados dos listas:
# - Preorden: orden de visita raíz → izquierda → derecha
# - Inorden: izquierda → raíz → derecha
#
# Implementa una función que reconstruya el árbol binario original.
#
# > 🧩 Este ejercicio implica identificar correctamente la raíz y subárboles en cada paso recursivo.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - Este es distinto a los patrones que ya practicaste: aquí no recorres un árbol que ya existe, lo **construyes** a partir de dos secuencias. Aun así, sigue siendo recursivo — la pregunta es qué te dice cada secuencia.
# - El primer valor de `preorden` es siempre la raíz (¿por qué?, mira la definición de preorden). Ubica ese valor dentro de `inorden`: ¿qué representan los valores a su izquierda? ¿y los de su derecha?
# - Con esos dos "trozos" de `inorden` (izquierda y derecha de la raíz), y con la porción correspondiente de `preorden`, tienes dos subproblemas más pequeños del mismo tipo — ahí está la recursión.
# - Trabaja un ejemplo pequeño a mano: `preorden = [10, 5, 2, 7, 15]`, `inorden = [2, 5, 7, 10, 15]`. Dibuja el árbol que se reconstruye, un paso a la vez, antes de escribir código.

# %% [markdown]
# ---
#
# ## 🌿 Ejercicio 4: Convertir un BST en una lista enlazada ordenada
#
# Transforma un BST en una lista enlazada (solo con punteros a la derecha) con los nodos ordenados de menor a mayor.
#
# > ✅ Puedes reutilizar el recorrido inorden para obtener el orden correcto.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - ¿Qué recorrido, de los que ya conoces, visita los nodos de un BST en el orden que necesitas para esta lista? Ya deberías poder responder esto sin dudar.
# - Una vez tengas los nodos en el orden correcto, ¿qué hay que hacerle a cada uno para que deje de ser parte del árbol y pase a ser parte de una lista enlazada? (piensa en qué referencias sobran y cuáles hay que reasignar)
# - Dibuja un BST pequeño y, al lado, dibuja la lista enlazada resultante con flechas, antes de programar.

# %% [markdown]
# ---
#
# ## ⚖️ Ejercicio 5: Verificar si un árbol binario está balanceado
#
# Implementa una función `es_balanceado(nodo)` que retorne `True` si el árbol binario está balanceado (diferencia de altura entre hijos ≤ 1 en todos los nodos).
#
# > 🧠 Este ejercicio es clave para diseñar árboles eficientes.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - Esto es post-order otra vez, muy parecido a `altura(nodo)` de `teoria_arboles.ipynb` — pero además de calcular la altura, necesitas verificar la condición de balance **en cada nodo del camino**, no solo en la raíz.
# - ¿Se te ocurre una forma de calcular la altura Y verificar el balance en la misma pasada recursiva (una sola función), en vez de llamar `altura()` por separado en cada nodo? Piensa qué tendría que devolver esa función combinada.
# - Dibuja un árbol donde la raíz "parezca" balanceada (diferencia de altura ≤ 1 entre sus dos hijos) pero algún nodo interno no lo esté — así entiendes por qué no basta con revisar solo la raíz.

# %% [markdown]
# ---
#
# ## 🪓 Ejercicio 6: Eliminar un nodo con dos hijos en BST
#
# Implementa una función `eliminar(valor)` en un BST que permita:
# - Buscar y eliminar un nodo
# - Si el nodo tiene dos hijos, reemplázalo por su **sucesor inorden**
#
# > 🎯 Este es el caso más complejo en la operación de eliminación.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - Primero identifica los 3 casos por separado (dibuja un BST y elige un nodo de cada tipo): nodo hoja, nodo con un solo hijo, nodo con dos hijos. Los dos primeros son sencillos — ¿qué hay que reconectar en cada uno?
# - Para el caso de dos hijos: el **sucesor inorden** es el siguiente valor más grande. En un BST, ¿en qué subárbol tienes que buscarlo, y una vez ahí, hacia qué lado tienes que irte siempre para encontrar el mínimo?
# - Una vez encuentras el sucesor, ¿qué dos cosas tienes que hacer? (pista: no es solo "mover" el nodo — piensa en copiar su valor y luego eliminarlo de donde estaba, que ya es un caso más simple de los dos anteriores)
# - Traza a mano la eliminación del valor `50` en el BST `[50, 30, 70, 20, 40, 60, 80]` antes de programar.

# %% [markdown]
# ---
#
# ## 🔍 Ejercicio 7: Encontrar la k-ésima menor clave en un BST
#
# Implementa una función `k_menor(nodo, k)` que devuelva el k-ésimo valor más pequeño del árbol (según orden inorden).
#
# > 📊 Debe recorrer el árbol eficientemente sin almacenar todos los valores.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - ¿Qué recorrido te entrega los valores en el orden en que necesitas contarlos (1ro más pequeño, 2do más pequeño, ...)?
# - La pista "sin almacenar todos los valores" te está pidiendo que **cuentes** a medida que recorres, y que **te detengas** apenas llegues al k-ésimo, en vez de construir la lista completa y luego indexarla. ¿Cómo llevas ese contador a través de las llamadas recursivas?
# - Sobre el BST `[50, 30, 70, 20, 40, 60, 80]`, calcula a mano cuál es el 3er valor más pequeño, siguiendo el recorrido inorden paso a paso y llevando la cuenta.

# %% [markdown]
# ---
#
# ## 📚 Ejercicio 8: Devolver todos los caminos raíz-hoja
#
# Implementa una función `caminos_raiz_hoja(nodo)` que retorne una lista de listas con todos los caminos desde la raíz hasta las hojas.
#
# > Ejemplo de salida:
# ```
# [[10, 5, 2], [10, 5, 7], [10, 15]]
# ```

# %% [markdown]
# ### 🧭 Antes de programar
#
# - ¿Qué necesitas pasar hacia abajo, del padre a cada hijo, para que el hijo sepa "por dónde ha pasado hasta ahora"? Es el mismo patrón pre-order de `imprimir_profundidades` en `teoria_arboles.ipynb`, pero en vez de pasar un número, pasas una lista/camino acumulado.
# - ¿Cómo sabes, en un nodo dado, que debes "cerrar" el camino actual y agregarlo al resultado en vez de seguir bajando?
# - Sobre un árbol pequeño de 3 niveles, dibuja cada camino raíz-hoja como una lista, antes de escribir código.

# %% [markdown]
# ---
#
# ## 🔎 Ejercicio 9: Verificar si un árbol contiene una suma de ruta
#
# Implementa una función `tiene_suma_ruta(nodo, suma)` que retorne `True` si existe algún camino desde la raíz hasta una hoja que sume exactamente `suma`.

# %% [markdown]
# ### 🧭 Antes de programar
#
# - Mismo patrón pre-order del ejercicio anterior: en vez de pasar hacia abajo el camino completo, ¿qué versión "resumida" de esa información te alcanza para este problema? (pista: no necesitas la lista completa de valores, solo un número)
# - ¿Qué le pasas exactamente a la llamada recursiva sobre `nodo.left` y sobre `nodo.right`? ¿Restas o sumas el valor del nodo actual?
# - ¿Cuál es la condición exacta que debes chequear justo al llegar a una hoja?

# %% [markdown]
# ---
#
# ## 🧩 Ejercicio 10: Convertir un árbol binario en su representación por niveles (lista de listas)
#
# Crea una función `a_niveles(nodo)` que devuelva una lista de listas, donde cada sublista contiene los valores de los nodos en un mismo nivel del árbol.
#
# > 🧠 Este ejercicio combina recorrido BFS con estructuración de salida.
#
# ---

# %% [markdown]
# ### 🧭 Antes de programar
#
# - Es el mismo patrón BFS del ejercicio de "niveles" que ya resolviste en `ejercicios_1.ipynb` — la diferencia es la forma exacta de la salida (lista de listas en vez de imprimir).
# - Una técnica común: en cada vuelta del `while` de tu BFS, procesa **solo los nodos que ya estaban en la cola al empezar esa vuelta** (no los que se van agregando durante la misma vuelta) — eso te da un nivel completo de una vez. ¿Cómo sabes cuántos nodos "ya estaban" al empezar?
# - Simula a mano, con un árbol de 3 niveles, el contenido de la cola al inicio de cada vuelta del ciclo, y qué sublista deberías producir en cada una.
