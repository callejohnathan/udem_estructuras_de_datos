# %% [markdown]
# ---
#
# ## **🟢 Nivel 1: Conceptos Básicos**
# ### **1️⃣ Implementación Básica de una Pila**
# Implementa una **pila (stack)** desde cero con las siguientes operaciones: `push()`, `pop()`, `peek()`, `isEmpty()` y `size()`. Luego, prueba la estructura agregando y eliminando elementos.
#
# **Objetivo:** Comprender cómo funciona una pila y cómo manipular sus elementos.

# %%
from base import Stack, EmptyStack

# %% [markdown]
# ---
#
# ### **2️⃣ Inversión de una Secuencia de Números**
# Crea un programa que use una pila para invertir el orden de una secuencia de números ingresados por el usuario.
#
# Ejemplo:
# **Entrada:** `1, 2, 3, 4, 5`
# **Salida:** `5, 4, 3, 2, 1`
#
# **Objetivo:** Aplicar la propiedad **LIFO** en un caso práctico.

# %% [markdown]
# 🧠 **Antes de programar:** ¿por qué apilar y luego sacar todo produce automáticamente el orden invertido, sin que tengas que pensar en índices? Traza el estado de la pila para la entrada `1, 2, 3, 4, 5`: primero la secuencia de `push`, y luego la secuencia de `pop` mostrando en qué orden van saliendo.

# %% [markdown]
# ---
#
# ### **3️⃣ Retornar el elemento de la mitad de una pila**
#
# Dada una pila con `n` elementos, retorna el elemento que está en la posición de la mitad (contando desde la base), **sin perder ni desordenar** los demás elementos: al terminar, la pila debe quedar exactamente igual a como estaba antes de empezar.
#
# Si `n` es par, define tú un criterio consistente para elegir "la mitad" (por ejemplo, el más cercano a la base entre los dos de en medio) y documéntalo en tu solución.
#
# **Ejemplo:**
# ```
# Entrada (base → tope): [1, 2, 3, 4, 5]
# Salida: 3   (posición del medio, y la pila queda intacta: [1, 2, 3, 4, 5])
# ```
#
# **Restricción:** solo puedes usar operaciones de pila (`push`, `pop`, `peek`) — nada de listas ni índices directos sobre la estructura.
#
# **Objetivo:** practicar el uso de una **pila auxiliar** para "recordar temporalmente" elementos mientras navegas la estructura, y luego restaurar el estado original — una técnica que vas a repetir muchas veces en esta unidad.

# %% [markdown]
# 🧠 **Antes de programar:**
#
# * ¿Por qué esta operación requiere una pila auxiliar y no basta con la pila original? ¿Qué harías si intentaras leer directamente la posición del medio sin sacar nada?
# * Traza a mano, en una tabla como las de `teoria_pilas.ipynb`, qué le pasa a la pila original y a la auxiliar paso a paso para la entrada del ejemplo (`[1, 2, 3, 4, 5]`, base → tope). ¿Cuántos `pop` necesitas hacer antes de llegar al elemento del medio? ¿Cómo restauras el orden original al final?

# %% [markdown]
# ---
#
# ### **4️⃣ Verificación de Balanceo de Paréntesis**
# Diseña un algoritmo que determine si una expresión matemática tiene un **balance correcto** de paréntesis `()`, corchetes `[]` y llaves `{}`.
#
# Ejemplo válido: `{ [ ( ) ] }`
# Ejemplo inválido: `{ [ ( ] ) }`
#
# **Objetivo:** Usar pilas para evaluar estructuras anidadas.

# %% [markdown]
# 🧠 **Antes de programar:** define en español, sin código, tu regla para "apertura" y para "cierre" (¿qué haces con cada uno?). Luego traza a mano, en una tabla carácter por carácter, el ejemplo inválido `{ [ ( ] ) }` y encuentra en qué carácter exacto se detecta el error — compáralo con la traza de `"([{}])"` que ya viste en `teoria_pilas.ipynb`.

# %% [markdown]
# ---
#
# ## **🟡 Nivel 2: Aplicaciones Intermedias**
# ### **5️⃣ Conversión de Notación Infija a Postfija**
# Desarrolla un algoritmo que convierta una expresión matemática **infija** (convencional) a **postfija** (*Notación Polaca Inversa* - RPN).
#
# Ejemplo:
# **Entrada:** `(3 + 4) * 5`
# **Salida:** `3 4 + 5 *`
#
# **Objetivo:** Aplicar pilas en procesamiento de expresiones.

# %% [markdown]
# 🧠 **Antes de programar:** ¿qué señal LIFO estás usando acá? (Pista: cuando lees un operador, ¿qué pasa con los operadores de menor precedencia que ya estaban esperando?) Traza a mano, en una tabla "símbolo leído → estado de la pila de operadores → salida acumulada", la entrada `(3 + 4) * 5` hasta producir `3 4 + 5 *`.

# %% [markdown]
# ---
#
# ### **6️⃣ Evaluación de Expresiones Postfijas**
# Implementa un evaluador de expresiones postfijas usando una pila.
#
# Ejemplo:
# **Entrada:** `3 4 + 5 *`
# **Salida:** `35`
#
# **Objetivo:** Simular el procesamiento de operaciones matemáticas mediante pilas.

# %% [markdown]
# 🧠 **Antes de programar:** ¿por qué en postfija nunca necesitas paréntesis ni reglas de precedencia para saber en qué orden operar? Traza a mano la pila token por token para `3 4 + 5 *`: ¿qué haces cuando lees un número? ¿qué haces cuando lees un operador?

# %% [markdown]
# ---
#
# ### **7️⃣ Deshacer/Rehacer en un Editor de Texto**
# Simula la funcionalidad **deshacer (undo) y rehacer (redo)** en un editor de texto. Usa dos pilas: una para almacenar las acciones realizadas y otra para las acciones que se pueden rehacer.
#
# Ejemplo de operaciones:
# 1. `Escribir "Hola"`
# 2. `Escribir " Mundo"`
# 3. `Deshacer → "Hola"`
# 4. `Rehacer → "Hola Mundo"`
#
# **Objetivo:** Aplicar pilas en un problema realista de software.

# %% [markdown]
# 🧠 **Antes de programar:** ¿por qué se necesitan **dos** pilas y no una sola? Traza el estado de ambas pilas (deshacer / rehacer) para la secuencia del ejemplo, y agrega tú un quinto paso: `Escribir " de nuevo"` después del `Rehacer`. ¿Qué le debería pasar a la pila de "rehacer" en ese momento, y por qué?

# %% [markdown]
# ---
#
# ## **🔴 Nivel 3: Desafíos Avanzados**
# ### **8️⃣ Implementación de una Pila con un Arreglo Fijo**
# Implementa una pila con un **tamaño máximo fijo**. Agrega una validación para evitar el **desbordamiento (stack overflow)** cuando la pila está llena.
#
# **Objetivo:** Manejar restricciones de espacio en una estructura de datos.

# %% [markdown]
# 🧠 **Antes de programar:** ¿qué validación adicional necesita `push()` que no tenía la pila de `base.py`? Enumera, en español, todos los casos borde que tu implementación debe cubrir (pila vacía, pila llena, tamaño exacto al límite) antes de escribir la primera línea.

# %% [markdown]
# ---
#
# ### **9️⃣ Implementación de una Pila con Múltiples Mínimos**
# Crea una pila que, además de las operaciones básicas, tenga una función `getMin()` que devuelva el **valor mínimo actual** en la pila en **O(1)**.
#
# Ejemplo:
# 1. `push(5)`
# 2. `push(2)`
# 3. `push(7)`
# 4. `getMin() → 2`
# 5. `pop()`
# 6. `getMin() → 2`
#
# **Objetivo:** Desarrollar una optimización sobre la estructura de una pila.

# %% [markdown]
# 🧠 **Antes de programar:** si solo llevas el mínimo como una variable suelta, ¿qué se rompe cuando haces `pop()` y el mínimo que sale era justo ese? Traza a mano, con una segunda columna "mínimo actual" junto a tu pila, la secuencia `push(5), push(2), push(7), pop(), pop()` — ¿qué necesitas guardar en cada paso para que `getMin()` siga siendo correcto después de cada `pop`?

# %% [markdown]
# ---
#
# ### **🔟 Evaluación de una Pila de Llamadas de Funciones Recursivas**
# Simula una pila de llamadas de funciones y muestra cómo se almacena y resuelve una función recursiva.
#
# Ejemplo: Calcula el factorial de `n` y muestra el estado de la pila en cada paso.
#
# **Objetivo:** Relacionar pilas con la recursión y comprender la pila de ejecución en un programa.

# %% [markdown]
# 🧠 **Antes de programar:** para `factorial(4)`, dibuja a mano la pila de llamadas: ¿qué se apila cada vez que `factorial` se llama a sí misma, y en qué momento empiezan los `pop` (los "retornos")? Relaciona cada `push`/`pop` de tu traza con una llamada o un retorno concreto de la función.

# %% [markdown]
# ---
#
# ### **11. Diseño de una Máquina de Estados Usando Pilas**
# Implementa un sistema de navegación donde el usuario pueda moverse entre páginas web y usar las funciones de "atrás" y "adelante". Usa dos pilas para gestionar la navegación.
#
# Ejemplo:
# 1. `Visitar "Inicio"`
# 2. `Visitar "Perfil"`
# 3. `Atrás → "Inicio"`
# 4. `Adelante → "Perfil"`
#
# **Objetivo:** Aplicar pilas en un contexto de navegación en aplicaciones.

# %% [markdown]
# 🧠 **Antes de programar:** ¿por qué "atrás" necesita una pila y no basta con guardar solo la página actual? ¿Qué le pasa a la pila de "adelante" cuando el usuario visita una página **nueva** después de haber ido "atrás" un par de veces? Traza el estado de ambas pilas para la secuencia del ejemplo.
