# %% [markdown]
# # Ejercicios: Pilas vs. Colas (Parte 2)
#
# ## Estructuras de Datos
#
# Esta es la continuación de `ejercicios_pilas_colas_1_20262.ipynb`. Los siguientes 4 escenarios tienen un poco más de dificultad: ya no basta con identificar quién "entra y sale primero", también deben implementar una lógica adicional sobre la estructura elegida (contar, comparar tipos, acumular resultados o descartar elementos según una condición).
#
# Al igual que antes, ya cuentan con sus propias implementaciones de **Pila** y **Cola**. Para cada ejercicio:
#
# 1. **Elijan** la estructura (pila o cola) que resuelve el problema con la **mejor eficiencia posible**.
# 2. Justifiquen la elección con un **comentario** al inicio de la celda de código, explicando la complejidad (Big-O) de las operaciones y por qué la otra estructura no sería adecuada o sería menos eficiente.
# 3. **Implementen** las funciones solicitadas en el enunciado.

# %% [markdown]
# ---
# ## Ejercicio 1: Validador de sintaxis con múltiples delimitadores
#
# Un profesor quiere revisar automáticamente si el código fuente de sus estudiantes tiene bien balanceados los símbolos `(`, `)`, `[`, `]`, `{`, `}`. No basta con que la **cantidad** de símbolos de apertura y cierre coincida: cada símbolo de cierre debe corresponder exactamente con el **tipo** y el **orden** del último símbolo de apertura pendiente. Por ejemplo, `"([)]"` debe considerarse inválida aunque tenga la misma cantidad de cada símbolo.
#
# Implementa:
#
# - `es_valida(cadena)`: recibe un string que puede contener letras, números y los símbolos mencionados, y retorna `True` si todos los delimitadores están correctamente balanceados y anidados, o `False` en caso contrario (incluyendo el caso en que sobre algún símbolo de apertura sin cerrar, o aparezca un cierre sin apertura previa).
#
# ¿Qué estructura permite verificar el **tipo** y el **orden** de cierre correctos en O(1) por símbolo?

# %%
# Ejercicio 1: escriban aquí su solución

# %% [markdown]
# ---
# ## Ejercicio 2: Calculadora en notación postfija (RPN)
#
# Las calculadoras científicas antiguas (HP) evaluaban expresiones en **notación postfija**, donde los operadores van después de sus operandos y no se necesitan paréntesis. Por ejemplo, la expresión `"3 4 + 2 *"` equivale a `(3 + 4) * 2 = 14`.
#
# Implementa:
#
# - `evaluar_postfija(expresion)`: recibe un string con números y operadores (`+`, `-`, `*`, `/`) separados por espacios, y retorna el resultado numérico de evaluar la expresión, procesando los tokens de izquierda a derecha.
#
# Pista sobre el algoritmo: al leer un número se guarda; al leer un operador, se deben tomar los **dos últimos números guardados**, aplicarles el operador y volver a guardar el resultado en el mismo lugar de donde salieron los operandos.
#
# ¿Qué estructura les permite acceder siempre a los operandos más recientes en O(1)?

# %%
# Ejercicio 2: escriban aquí su solución

# %% [markdown]
# ---
# ## Ejercicio 3: El juego de la papa caliente
#
# En el juego de la "papa caliente", `n` jugadores se ubican en círculo y se van pasando una papa de mano en mano. Cada vez que se completan exactamente `k` pases, el jugador que queda con la papa es **eliminado** del círculo y el juego continúa con los jugadores restantes, retomando el conteo desde el siguiente jugador. El juego termina cuando queda un único jugador: el ganador.
#
# Implementa:
#
# - `jugar_papa_caliente(jugadores, k)`: recibe una lista de nombres (en el orden en que están sentados en el círculo) y el número de pases `k`, y retorna una tupla `(orden_de_eliminacion, ganador)`, donde `orden_de_eliminacion` es la lista de jugadores en el orden en que fueron quedando eliminados.
#
# Pista sobre el algoritmo: simular cada "pase" de la papa como sacar al jugador del frente y volver a ubicarlo al final, sin usar índices ni recorrer una lista manualmente.
#
# ¿Qué estructura modela naturalmente el círculo de jugadores y el paso de la papa con operaciones O(1)?

# %%
# Ejercicio 3: escriban aquí su solución

# %% [markdown]
# ---
# ## Ejercicio 4: Servidor con solicitudes que expiran
#
# Un servidor web recibe solicitudes que deben procesarse **en el mismo orden en que llegaron**. Sin embargo, cada solicitud trae un tiempo límite de espera (TTL): si cuando le toca su turno ya lleva esperando más tiempo del permitido, debe **descartarse sin procesar**, y se debe seguir con la siguiente solicitud en orden de llegada (que también podría estar vencida).
#
# Implementa:
#
# - `procesar_solicitudes(solicitudes, tiempo_actual)`: recibe una lista de tuplas `(id_solicitud, tiempo_llegada, ttl)` en el orden en que llegaron, y el `tiempo_actual` del servidor. Debe retornar una tupla `(procesadas, descartadas)` con los `id_solicitud` de cada grupo, respetando siempre el orden original de llegada dentro de cada lista. Una solicitud está vencida si `tiempo_actual - tiempo_llegada > ttl`.
#
# ¿Qué estructura les permite revisar la solicitud más antigua (la del frente) sin alterar el orden de llegada del resto, con operaciones O(1)?

# %%
# Ejercicio 4: escriban aquí su solución
