# %% [markdown]
# # Ejercicios: Pilas vs. Colas
#
# ## Estructuras de Datos
#
# En cada uno de los siguientes ejercicios se plantea una situación. Ya cuentan con sus propias implementaciones de **Pila** y **Cola** (con sus métodos correspondientes, por ejemplo `apilar` / `desapilar` / `tope`, y `encolar` / `decolar` / `frente`, además de `esta_vacia`).
#
# Para cada ejercicio deben:
#
# 1. **Elegir** cuál de las dos estructuras (pila o cola) permite resolver el problema con la **mejor eficiencia posible**.
# 2. Justificar la elección con un **comentario** al inicio de la celda de código, mencionando la complejidad (Big-O) de las operaciones involucradas y por qué la otra estructura sería menos adecuada o menos eficiente.
# 3. **Implementar** las funciones solicitadas en el enunciado, usando la estructura elegida (pueden importar o pegar su propia clase si lo necesitan).
#
# No hay una celda de código "vacía por defecto": usen la celda debajo de cada enunciado para resolverlo.

# %% [markdown]
# ---
# ## Ejercicio 1: Deshacer cambios en un editor de texto
#
# Estás implementando la funcionalidad de **"Deshacer" (Ctrl+Z)** de un editor de texto simple. Cada vez que el usuario realiza una acción (por ejemplo, `"escribir letra"`, `"borrar palabra"`, `"pegar texto"`), esta se registra en el sistema. Cuando el usuario presiona deshacer, el editor debe revertir **la acción más reciente**, y así sucesivamente: la última acción registrada debe ser siempre la primera en deshacerse.
#
# Implementa:
#
# - `registrar_accion(estructura, accion)`: agrega una nueva acción al registro.
# - `deshacer(estructura)`: retorna la acción que debe deshacerse y la elimina del registro.
#
# ¿Qué estructura permite que ambas operaciones se realicen en tiempo O(1), respetando el orden en que el usuario espera que se deshagan sus acciones?

# %%
# Ejercicio 1: escriban aquí su solución

# %% [markdown]
# ---
# ## Ejercicio 2: Atención en la ventanilla única de un banco
#
# Un banco cuenta con una **única ventanilla** de atención. Los clientes van llegando durante la mañana y deben ser atendidos estrictamente en el orden en que llegaron: quien llega primero, es atendido primero. No existe la posibilidad de "saltarse" turnos.
#
# Implementa:
#
# - `llegar_cliente(estructura, nombre)`: registra la llegada de un nuevo cliente.
# - `atender_cliente(estructura)`: retorna el nombre del cliente que debe ser atendido y lo retira de la fila.
#
# ¿Qué estructura garantiza, con operaciones O(1), que el orden de atención respete siempre el orden estricto de llegada?

# %%
# Ejercicio 2: escriban aquí su solución

# %% [markdown]
# ---
# ## Ejercicio 3: Historial de navegación (solo botón "Atrás")
#
# Un navegador web simplificado solo implementa el botón **"Atrás"** (no tiene botón "Adelante"). Cada vez que el usuario visita una nueva página, la URL se agrega al historial. Al presionar "Atrás", el usuario debe volver **a la página que visitó inmediatamente antes de la actual**.
#
# Implementa:
#
# - `visitar_pagina(estructura, url)`: registra la visita a una nueva página.
# - `regresar(estructura)`: retorna la URL a la que el usuario debe regresar y la elimina del historial.
#
# ¿Qué estructura resuelve este comportamiento de forma más eficiente, en O(1) por operación?

# %%
# Ejercicio 3: escriban aquí su solución

# %% [markdown]
# ---
# ## Ejercicio 4: Impresora compartida en un laboratorio de cómputo
#
# En un laboratorio de cómputo hay una **única impresora** compartida por todos los estudiantes. Cuando alguien envía un documento a imprimir, este debe esperar su turno: los documentos deben imprimirse exactamente **en el mismo orden en que fueron enviados**, sin importar cuánto tiempo lleve cada uno en espera.
#
# Implementa:
#
# - `enviar_documento(estructura, documento)`: agrega un documento a la fila de impresión.
# - `imprimir_siguiente(estructura)`: retorna el documento que debe imprimirse a continuación y lo remueve de la fila.
#
# ¿Qué estructura asegura, con operaciones O(1), que el primer documento enviado sea siempre el primero en imprimirse?

# %%
# Ejercicio 4: escriban aquí su solución
